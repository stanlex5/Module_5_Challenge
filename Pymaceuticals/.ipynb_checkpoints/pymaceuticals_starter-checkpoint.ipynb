# %% [markdown]
# # Pymaceuticals Inc.
# ---
#
# ### Analysis
#
# - Add your analysis here.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
import scipy.stats as st
from scipy.stats import linregress

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single DataFrame
Combined_data = pd.merge(mouse_metadata, study_results, how='outer')

# Display the data table for preview
Combined_data.head()
# Out:
#   Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0     k403     Ramicane  Male          21          16          0
# 1     k403     Ramicane  Male          21          16          5
# 2     k403     Ramicane  Male          21          16         10
# 3     k403     Ramicane  Male          21          16         15
# 4     k403     Ramicane  Male          21          16         20
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           45.000000                 0
# 1           38.825898                 0
# 2           35.014271                 1
# 3           34.223992                 1
# 4           32.997729                 1

# %%
# Checking the number of mice.
mice=Combined_data["Mouse ID"].value_counts()
number_of_mice=len(mice)
number_of_mice
# Out:
# 249

# %%
# Our data should be uniquely identified by Mouse ID and Timepoint
# Get the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
duplicate_mice = Combined_data.loc[Combined_data.duplicated(subset=['Mouse ID', 'Timepoint',]),'Mouse ID'].unique()

# %%
# Optional: Get all the data for the duplicate mouse ID. 
all_duplicate_mouse_id=pd.DataFrame(duplicate_mice)
all_duplicate_mouse_id
# Out:
#       0
# 0  g989

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
clean_df = Combined_data[Combined_data['Mouse ID'].isin(duplicate_mice)==False]

# %%
# Checking the number of mice in the clean DataFrame.
clean_mice=clean_df["Mouse ID"].value_counts()
clean_number_of_mice=len(clean_mice)
clean_number_of_mice
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary DataFrame.

means = Combined_data.groupby('Drug Regimen').mean()['Tumor Volume (mm3)']
medians = Combined_data.groupby('Drug Regimen').median()['Tumor Volume (mm3)']
variances = Combined_data.groupby('Drug Regimen').var()['Tumor Volume (mm3)']
standards = Combined_data.groupby('Drug Regimen').std()['Tumor Volume (mm3)']
sems = Combined_data.groupby('Drug Regimen').sem()['Tumor Volume (mm3)']

newtable = pd.DataFrame(means)
newtable2 = newtable.rename(columns={"Tumor Volume (mm3)": "Mean Tumor Volume"})

newtable2["Median Tumor Volume"] = medians
newtable2["Tumor Volume Variance"] = variances
newtable2["Tumor Volume Std. Dev"] = standards
newtable2["Tumor Volume Std. Err"] = sems

newtable2
# Out:
#               Mean Tumor Volume  Median Tumor Volume  Tumor Volume Variance  \
# Drug Regimen
# Capomulin             40.675741            41.557809              24.947764
# Ceftamin              52.591172            51.776157              39.290177
# Infubinol             52.884795            51.820584              43.128684
# Ketapril              55.235638            53.698743              68.553577
# Naftisol              54.331565            52.509285              66.173479
# Placebo               54.033581            52.288934              61.168083
# Propriva              52.322552            50.854632              42.351070
# Ramicane              40.216745            40.673236              23.486704
# Stelasyn              54.233149            52.431737              59.450562
# Zoniferol             53.236507            51.818479              48.533355
#
#               Tumor Volume Std. Dev  Tumor Volume Std. Err
# Drug Regimen
# ...

# %%
# A more advanced method to generate a summary statistics table of mean, median, variance, standard deviation,
# and SEM of the tumor volume for each regimen (only one method is required in the solution)

# Using the aggregation method, produce the same summary statistics in a single line

Similar = Combined_data.groupby('Drug Regimen')
first = Similar.agg(['mean','median','var','std','sem'])["Tumor Volume (mm3)"]
first
# Out:
# C:\Users\stane\AppData\Local\Temp\ipykernel_29188\2561476686.py:7: FutureWarning: ['Mouse ID', 'Sex'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   first = Similar.agg(['mean','median','var','std','sem'])["Tumor Volume (mm3)"]
#                    mean     median        var       std       sem
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva      52.322552  50.854632  42.351070  6.507770  0.512884
# Ramicane      40.216745  40.673236  23.486704  4.846308  0.320955
# ...

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using Pandas.
Total = Combined_data.groupby(["Drug Regimen"]).count()["Mouse ID"] 


plot_pandas = Total.plot.bar(figsize=(5,5), color='b',fontsize = 10)
Total
plt.xlabel("Drug Regimen",fontsize = 10)
plt.ylabel("# of Observed Mouse Timepoints",fontsize = 10)
plt.tight_layout()
plt.show()

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using pyplot.

list_of_mice =(Combined_data.groupby(["Drug Regimen"])["Mouse ID"].count()).tolist()
x_axis = np.arange(len(Total))
fig1, ax1 = plt.subplots(figsize=(5, 5))
plt.bar(x_axis, list_of_mice, color='b', alpha=0.8, align='center')

tick_locations = [value for value in x_axis]

plt.xticks(tick_locations, ['Capomulin', 'Ceftamin', 'Infubinol', 'Ketapril', 'Naftisol', 'Placebo', 'Propriva', 'Ramicane', 'Stelasyn', 'Zoniferol'],  rotation='vertical')

plt.xlim(-0.75, len(x_axis)-0.25)

plt.ylim(0, max(list_of_mice)+10)


plt.xlabel("Drug Regimen",fontsize = 10)
plt.ylabel("# of Observed Mouse Timepoints",fontsize = 10)
# Out:
# Text(0, 0.5, '# of Observed Mouse Timepoints')

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas

Gender_DF= Combined_data["Sex"].value_counts()
Gender_DF.plot(kind="pie",ylabel="Sex",autopct= "%1.1f%%")
plt.title("Female vs Male")
# Out:
# Text(0.5, 1.0, 'Female vs Male')

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot

labels=["Male","Female"]
y= Combined_data["Sex"].value_counts()
plt.pie(y,labels=labels,autopct = "%1.1f%%")
plt.title("Female vs Male")
plt.ylabel("Sex")
# Out:
# Text(0, 0.5, 'Sex')

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and ceftamin

# Start by getting the last (greatest) timepoint for each mouse
greatest_timepoint = Combined_data.groupby("Mouse ID")["Timepoint"].max()
greatest_timepoint_df=pd.DataFrame(greatest_timepoint)
greatest_timepoint_df.reset_index()


# Merge this group df with the original DataFrame to get the tumor volume at the last timepoint
Tumor_volume_df=pd.merge(Combined_data,greatest_timepoint_df,on=["Mouse ID" ,"Timepoint"])
Tumor_volume_df.head(35)
# Out:
#    Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0      k403     Ramicane    Male          21          16         45
# 1      s185    Capomulin  Female           3          17         45
# 2      x401    Capomulin  Female          16          15         45
# 3      m601    Capomulin    Male          22          17         45
# 4      g791     Ramicane    Male          11          16         45
# 5      s508     Ramicane    Male           1          17         45
# 6      f966    Capomulin    Male          16          17         20
# 7      m546     Ramicane    Male          18          16         45
# 8      z578     Ramicane    Male          11          16         45
# 9      j913     Ramicane  Female           4          17         45
# 10     u364    Capomulin    Male          18          17         45
# 11     n364     Ramicane    Male           4          17         45
# 12     y793    Capomulin    Male          17          17         45
# ...

# %%
# Put treatments into a list for for loop (and later for plot labels)

Treatment_regimen=["Capomulin","Ramicane", "Infubinol","Ceftamin"]

# Create empty list to fill with tumor vol data (for plotting)
Tumor_volume_data=[]
# Calculate the IQR and quantitatively determine if there are any potential outliers. 

    
    # Locate the rows which contain mice on each drug and get the tumor volumes
for regimen in Treatment_regimen:
    volume_val=  Tumor_volume_df.loc[Tumor_volume_df["Drug Regimen"]==regimen, "Tumor Volume (mm3)"]
    Tumor_volume_data.append(volume_val)
    
    # add subset 
  
    quartiles = volume_val.quantile([.25,.5,.75])
    upperquart = quartiles[0.75]
    lowerquart = quartiles[0.25]
    iqr = upperquart-lowerquart

    lower_bound = lowerquart - (1.5*iqr)
    upper_bound = upperquart + (1.5*iqr)
    outlier = (volume_val.loc[(Tumor_volume_df["Tumor Volume (mm3)"]>=upper_bound)|
                                        (Tumor_volume_df["Tumor Volume (mm3)"]<=lower_bound)])

    
    outlier_count=outlier.count()
    print(f"{regimen}'s \n   InterQuartile Range (IQR): {iqr}")
   

    print(f"   potential outliers:{outlier_count},  {outlier}")
# Out:
# Capomulin's
#    InterQuartile Range (IQR): 7.781863460000004
#    potential outliers:0,  Series([], Name: Tumor Volume (mm3), dtype: float64)
# Ramicane's
#    InterQuartile Range (IQR): 9.098536719999998
#    potential outliers:0,  Series([], Name: Tumor Volume (mm3), dtype: float64)
# Infubinol's
#    InterQuartile Range (IQR): 11.477135160000003
#    potential outliers:1,  74    36.321346
# Name: Tumor Volume (mm3), dtype: float64
# Ceftamin's
#    InterQuartile Range (IQR): 15.577752179999997
#    potential outliers:0,  Series([], Name: Tumor Volume (mm3), dtype: float64)

# %%
# Generate a box plot that shows the distrubution of the tumor volume for each treatment group.
fig1, ax1 = plt.subplots()
#flierprops = dict(marker='o', markerfacecolor='r', markersize=8)
#flierprops = dict(marker='o', markerfacecolor='r', markersize=8, markeredgecolor='black')

ax1.boxplot(Tumor_vol_data)
ax1.set_title('Final Tumor Volume by Regimen')
ax1.set_ylabel('Final Tumor Volume')

plt.xticks([1, 2, 3, 4], ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin'])
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a single mouse treated with Capomulin

Capomulin_Mouse = Combined_data.loc[Combined_data['Mouse ID'] == 'l509']

# Plot a line chart with the time values on the x-axis and the tumor volume values on the y-axis
# marker = 'o' adds circles on each data point for visibility
plt.plot(Capomulin_Mouse['Timepoint'], Capomulin_Mouse['Tumor Volume (mm3)'])

# display labels and title to plot
plt.xlabel("Time (days)")
plt.ylabel("Tumor Volume (mm3)")
plt.title("Capomulin Treatment of Mouse l509")

# Display plot
plt.show()

# %%
# Generate a scatter plot of mouse weight vs. the average observed tumor volume for the entire Capomulin regimen

Capomulin_DF= Combined_data.loc[Combined_data["Drug Regimen"]=="Capomulin"].groupby("Mouse ID")
Capomulin_DF.head()
average_tumor_volume=Capomulin_DF['Tumor Volume (mm3)'].mean()
average_mouse_weight = Capomulin_DF["Weight (g)"].unique()



plt.scatter(average_mouse_weight,average_tumor_volume)
plt.xlabel("Weight (g)")
plt.ylabel("Average Tumor Volume (mm3)")
plt.title('Average Tumor Volume by Weight')

plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and a linear regression model 
# for mouse weight and average observed tumor volume for the entire Capomulin regimen


average_mouse_weight = average_mouse_weight.astype(float)
correlation = st.pearsonr(average_mouse_weight, average_tumor_volume)

x=average_mouse_weight
y=average_tumor_volume
(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(average_mouse_weight, average_tumor_volume)
plt.plot(average_mouse_weight, regress_values, "r-")
plt.title("Correlation and Regression")
plt.xlabel("Weight (g)")
plt.ylabel("Average Tumor Volume (mm3)")
print(f"The correlation between the mouse weight and the average tumor volume is {round(correlation[0], 2)}.")
plt.show()
# Out:
# The correlation between the mouse weight and the average tumor volume is 0.84.
